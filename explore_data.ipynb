# %%
import pandas as pd

# %%
cepii = pd.read_csv('../data/raw/Cepii_centrality_measures.csv', sep=';')

# %%
cepii.head()
# Out:
#       t  id    i iso3 country  Out-degree  In-degree  Out-strength  \
# 0  2010   1  533  ABW   Aruba    0.361582   0.508475      1579.159
# 1  2009   1  533  ABW   Aruba    0.429378   0.542373     11615.680
# 2  2008   1  533  ABW   Aruba    0.367232   0.401130     29023.210
# 3  2007   1  533  ABW   Aruba    0.355932   0.372881     24328.210
# 4  2006   1  533  ABW   Aruba    0.293785   0.350282     22036.800
#
#    In-strength  Out-degree_percent  ...  Out-strength-percent  \
# 0     7207.833            0.294037  ...              0.001908
# 1     7411.798            0.356439  ...              0.017198
# 2    14725.500            0.293865  ...              0.032732
# 3    14732.210            0.286338  ...              0.032068
# 4    17054.310            0.239687  ...              0.033394
#
#    In-strength_percent  Out-closenness  In-closenness  W-Out-closenness  \
# 0             0.008708        0.610345       0.670455          0.092015
# ...
